# %% [markdown]
# I have used a custom dataset which i already downloaded link->[https://www.kaggle.com/datasets/splcher/animefacedataset]

# %%
import os
import torch
import torchvision
import torch.nn as nn

from torchvision.utils import make_grid
from torch.utils.data import DataLoader
import torch.nn.functional as f
from torchvision.datasets import ImageFolder
import torchvision.transforms as t
from torchvision.utils import save_image

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_dir="./Dataset2"
print(os.listdir(img_dir))
# Out:
# ['images']

# %%
stats=((0.5,0.5,0.5),(0.5,0.5,0.5))

# %%
train_dl=ImageFolder(img_dir,transform=t.Compose([
                t.Resize(64),
                t.CenterCrop(64),
                t.ToTensor(),
                t.Normalize(*(stats))]))

# %%
train_dl=DataLoader(train_dl,128,shuffle=True,num_workers=3,pin_memory=True)

# %%
def denorm(img):
    return img*stats[1][0] +stats[0][0]

# %%
def show_img_norm(img):
    fig,ax=plt.subplots(figsize=(16,16))
    ax.set_xticks([]);ax.set_yticks([])
    plt.imshow(make_grid(denorm(img),nrow=16).permute(1,2,0))
def show_img(img):
    fig,ax=plt.subplots(figsize=(16,16))
    ax.set_xticks([]);ax.set_yticks([])
    plt.imshow(make_grid(img,nrow=16).permute(1,2,0))

def show_bth(batch):
    for i,_ in batch:
        show_img_norm(i)
        break

# %%
show_bth(train_dl)

# %%
def get_default_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    else:
        return torch.device("cpu")
    
def to_device(data,device):
    if isinstance(data,(list,tuple)):
        return [to_device(x,device)for x in data]
    return data.to(device,non_blocking=True)

class devicedataloader():
    def __init__(self,dl,device):
        self.dl=dl
        self.device=device

    def __iter__(self):
        for a in self.dl:
            yield to_device(a,device=self.device)

    def __len__(self):
        return len(self.dl)

# %%
device=get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl=devicedataloader(train_dl,device)

# %%
discriminator=nn.Sequential(

            nn.Conv2d(3,64,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2,inplace=True),

            nn.Conv2d(64,128,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2,inplace=True),

            nn.Conv2d(128,256,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2,inplace=True),

            nn.Conv2d(256,512,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2,inplace=True),

            nn.Conv2d(512,1,kernel_size=4,stride=1,padding=0,bias=False),
            
            nn.Flatten(),
            nn.Sigmoid()
)

# %%
discriminator=to_device(discriminator,device)

# %%
generator = nn.Sequential(
            nn.ConvTranspose2d(128,512,kernel_size=4,stride=1,padding=0,bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            nn.ConvTranspose2d(512,256,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.ConvTranspose2d(256,128,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.ConvTranspose2d(128,64,kernel_size=4,stride=2,padding=1,bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),

            nn.ConvTranspose2d(64,3,kernel_size=4,stride=2,padding=1,bias=False),
            nn.Tanh()
)

# %%
generator=to_device(generator,device)

# %%
def train_discriminator(real_img,opt_d):
    opt_d.zero_grad()

    real_preds=discriminator(real_img)
    preds=torch.ones(real_img.size(0),1,device=device)
    real_loss=f.binary_cross_entropy(real_preds,preds)
    real_score=torch.mean(real_loss).item()

    latent=torch.randn(128,128,1,1,device=device)
    fake_img=generator(latent)

    fake_preds=discriminator(fake_img)
    preds=torch.zeros(fake_img.size(0),1,device=device)
    fake_loss=f.binary_cross_entropy(fake_preds,preds)
    fake_score=torch.mean(fake_loss).item()

    loss=real_loss+fake_loss
    loss.backward()
    opt_d.step()

    return loss.item(),real_score,fake_score

# %%
def train_generator(opt_g):
    opt_g.zero_grad()

    latent=torch.randn(128,128,1,1,device=device)
    fake_img=generator(latent)
    preds=discriminator(fake_img)
    org_preds=torch.ones(fake_img.size(0),1,device=device)
    loss=f.binary_cross_entropy(preds,org_preds)

    loss.backward()
    opt_g.step()

    return loss.item()

# %%
sample_dir = 'generated2'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, 128, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-images-0000.png

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in(train_dl):
            
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            
            loss_g = train_generator(opt_g)
            
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
history = fit(25, 0.000055)
# Out:
# Epoch [1/25], loss_g: 7.7985, loss_d: 0.4348, real_score: 0.0180, fake_score: 0.4169
# Saving generated-images-0001.png
# Epoch [2/25], loss_g: 5.3228, loss_d: 0.1684, real_score: 0.1152, fake_score: 0.0532
# Saving generated-images-0002.png
# Epoch [3/25], loss_g: 5.6728, loss_d: 0.2944, real_score: 0.1011, fake_score: 0.1932
# Saving generated-images-0003.png
# Epoch [4/25], loss_g: 3.1654, loss_d: 0.3474, real_score: 0.3113, fake_score: 0.0361
# Saving generated-images-0004.png
# Epoch [5/25], loss_g: 4.4434, loss_d: 0.1887, real_score: 0.0739, fake_score: 0.1148
# Saving generated-images-0005.png
# Epoch [6/25], loss_g: 4.3091, loss_d: 0.1444, real_score: 0.0544, fake_score: 0.0901
# Saving generated-images-0006.png
# Epoch [7/25], loss_g: 5.4662, loss_d: 1.8469, real_score: 1.8469, fake_score: 0.0000
# Saving generated-images-0007.png
# Epoch [8/25], loss_g: 4.6002, loss_d: 0.1335, real_score: 0.0311, fake_score: 0.1024
# Saving generated-images-0008.png
# Epoch [9/25], loss_g: 2.9770, loss_d: 0.1574, real_score: 0.1363, fake_score: 0.0210
# Saving generated-images-0009.png
# Epoch [10/25], loss_g: 3.7957, loss_d: 0.1405, real_score: 0.1027, fake_score: 0.0378
# Saving generated-images-0010.png
# Epoch [11/25], loss_g: 7.1578, loss_d: 0.0361, real_score: 0.0223, fake_score: 0.0138
# Saving generated-images-0011.png
# Epoch [12/25], loss_g: 4.2759, loss_d: 0.1252, real_score: 0.0688, fake_score: 0.0565
# Saving generated-images-0012.png
# Epoch [13/25], loss_g: 4.1914, loss_d: 0.1340, real_score: 0.0915, fake_score: 0.0425
# Saving generated-images-0013.png
# Epoch [14/25], loss_g: 3.7870, loss_d: 0.1453, real_score: 0.0821, fake_score: 0.0632
# Saving generated-images-0014.png
# Epoch [15/25], loss_g: 4.0169, loss_d: 0.1421, real_score: 0.0342, fake_score: 0.1079
# Saving generated-images-0015.png
# Epoch [16/25], loss_g: 4.2994, loss_d: 0.1040, real_score: 0.0486, fake_score: 0.0554
# Saving generated-images-0016.png
# Epoch [17/25], loss_g: 4.5261, loss_d: 0.0991, real_score: 0.0438, fake_score: 0.0553
# Saving generated-images-0017.png
# Epoch [18/25], loss_g: 3.1850, loss_d: 0.1258, real_score: 0.0974, fake_score: 0.0284
# Saving generated-images-0018.png
# Epoch [19/25], loss_g: 4.3425, loss_d: 0.0837, real_score: 0.0599, fake_score: 0.0238
# Saving generated-images-0019.png
# Epoch [20/25], loss_g: 3.8289, loss_d: 0.1145, real_score: 0.0653, fake_score: 0.0492
# Saving generated-images-0020.png
# Epoch [21/25], loss_g: 3.6738, loss_d: 0.0623, real_score: 0.0407, fake_score: 0.0216
# Saving generated-images-0021.png
# Epoch [22/25], loss_g: 3.9233, loss_d: 0.0801, real_score: 0.0410, fake_score: 0.0391
# Saving generated-images-0022.png
# Epoch [23/25], loss_g: 5.3730, loss_d: 0.1110, real_score: 0.0276, fake_score: 0.0834
# Saving generated-images-0023.png
# Epoch [24/25], loss_g: 6.2151, loss_d: 0.1072, real_score: 0.0193, fake_score: 0.0879
# Saving generated-images-0024.png
# Epoch [25/25], loss_g: 4.4569, loss_d: 0.0988, real_score: 0.0841, fake_score: 0.0147
# Saving generated-images-0025.png
